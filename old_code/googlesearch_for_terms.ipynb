# %%
from googlesearch import search 
import pandas as pd
import re
from datetime import datetime

qterm = 'access to and use of Locality Labs'
query = '"{}" site:.com/terms'.format(qterm)
  
js = [j for j in search(query, tld="com", num=1000, stop=None, pause=2.0,
                        extra_params={'filter': '0'})]
js
# Out:
# ['http://newsroom.westandforprogress.com/terms',
#  'https://fdahealthnews.com/terms',
#  'https://metrobusinessnetwork.com/terms',
#  'https://patientdaily.com/terms',
#  'https://tobacconewswire.com/terms',
#  'https://megadealernews.com/terms',
#  'https://hrdailywire.com/terms',
#  'https://wealthmanagementwire.com/terms',
#  'https://surprisejournal.com/terms',
#  'https://mdstatewire.com/terms',
#  'https://propertyinsurancewire.com/terms',
#  'https://cars.statesman.com/terms',
#  'https://fdareporter.com/terms',
#  'https://americanpharmacynews.com/terms',
#  'https://baltimorecitywire.com/terms',
#  'https://southcentralreporter.com/terms',
#  'https://prairiestatewire.com/terms',
#  'https://doctorphillipstoday.com/terms',
#  'https://quincyreporter.com/terms',
#  'https://rockislandtoday.com/terms',
#  'http://louisianarecord.pli-records-staging.locallabs.com/terms',
#  'https://gothatoday.com/terms',
#  'https://albusinessdaily.com/terms',
#  'https://ribusinessdaily.com/terms',
#  'http://pennrecord.pli-records-staging.locallabs.com/terms',
#  'https://collegeparktoday.com/terms',
#  'https://gulfnewsjournal.com/terms',
#  'https://kankakeetimes.com/terms',
#  'https://hansondirectory.com/terms',
#  'https://homes1.statesman.com/terms',
#  'https://mcleancountytimes.com/terms',
#  'https://willcountygazette.com/terms',
#  'https://cropprotectionnews.com/terms',
#  'https://cistranfinance.com/terms',
#  'https://mchenrytimes.com/terms',
#  'https://epnewswire.com/terms',
#  'https://montgomerymdnews.com/terms',
#  'https://hunterscreeknews.com/terms',
#  'https://nwillinoisnews.com/terms',
#  'https://lakebutlernews.com/terms',
#  'https://illinoisvalleytimes.com/terms',
#  'https://seillinoisnews.com/terms',
#  'https://lakebuenavistanews.com/terms',
#  'https://urbandaletimes.com/terms',
#  'https://northegyptnews.com/terms',
#  'https://mdbusinessdaily.com/terms',
#  'https://annearundeltoday.com/terms',
#  'https://eastcentralreporter.com/terms',
#  'https://sangamonsun.com/terms',
#  'https://metroeastsun.com/terms',
#  'http://wvrecord.pli-records-staging.locallabs.com/terms',
#  'https://dekalbtimes.com/terms',
#  'https://rockfordsun.com/terms',
#  'https://balkanbusinesswire.com/terms',
#  'https://silnews.com/terms',
#  'https://chicagocitywire.com/terms',
#  'https://northbaltimorejournal.com/terms',
#  'https://apopkatimes.com/terms',
#  'https://cretereview.com/terms',
#  'https://grundyreporter.com/terms',
#  'https://westcentralreporter.com/terms',
#  'https://kendallcountytimes.com/terms',
#  'https://carbondalereporter.com/terms',
#  'https://clivenews.com/terms',
#  'https://northcooknews.com/terms',
#  'https://lakecountygazette.com/terms',
#  'https://windermeretoday.com/terms',
#  'https://maconreporter.com/terms',
#  'https://southcooknews.com/terms',
#  'https://westcooknews.com/terms',
#  'https://waukeetimes.com/terms',
#  'https://galesburgreporter.com/terms',
#  'https://dupagepolicyjournal.com/terms',
#  'https://howardconews.com/terms',
#  'https://kanecountyreporter.com/terms',
#  'https://baldwinparktoday.com/terms',
#  'https://harfordnews.com/terms',
#  'https://glendalesun.com/terms',
#  'https://chambanasun.com/terms',
#  'https://lansingreporter.com/terms',
#  'https://goldenrodnews.com/terms',
#  'https://farminsurancenews.com/terms',
#  'https://swillinoisnews.com/terms',
#  'https://johnstontimes.com/terms',
#  'https://annarbortimes.com/terms',
#  'https://torontobusinessdaily.com/terms',
#  'https://lynwoodtimes.com/terms',
#  'https://grimesjournal.com/terms',
#  'https://westdesmoinesguide.com/terms',
#  'https://manilabusinessdaily.com/terms',
#  'https://norwalktimes.com/terms',
#  'https://peoriastandard.com/terms',
#  'https://micapitolnews.com/terms',
#  'https://sturgiscoldwaternews.com/terms',
#  'https://battlecreektimes.com/terms',
#  'https://wcminnesotanews.com/terms',
#  'https://northwakenews.com/terms',
#  'https://ncunionnews.com/terms']

# %%
# Save, and compare against existing site list
newsites = [re.findall('//(.*)/', x)[0] for x in js]
df = pd.DataFrame(newsites, columns=['url']).sort_values('url')
df.to_csv('googlesearch_{}.csv'.format(datetime.now().strftime('%Y-%m-%d-%H-%M')),
          index=False)

df2 = pd.read_csv('pink_slime_sites - from_sites.csv')
fromsites = df2['URL'].to_list()
fromsites = [re.findall('//(.*)', x)[0].strip('/') for x in fromsites]
df3 = pd.DataFrame(list(set(newsites) - set(fromsites)), columns=['url'])
df3.to_csv('temp.csv', index=False)
df3
# Out:
#                                                   url
# 0                     newsroom.westandforprogress.com
# 1                             manilabusinessdaily.com
# 2   louisianarecord.pli-records-staging.locallabs.com
# 3                              lakebuenavistanews.com
# 4                                     apopkatimes.com
# 5                                baldwinparktoday.com
# 6                                   grimesjournal.com
# 7                                 ribusinessdaily.com
# 8                                  cars.statesman.com
# 9                            torontobusinessdaily.com
# 10                                gulfnewsjournal.com
# 11                                mdbusinessdaily.com
# 12                                   lynwoodtimes.com
# 13                            doctorphillipstoday.com
# 14                                 lakebutlernews.com
# 15                                 urbandaletimes.com
# 16                                lansingreporter.com
# 17                                  goldenrodnews.com
# 18                                    fdareporter.com
# 19                                tobacconewswire.com
# 20                                 megadealernews.com
# 21                                   norwalktimes.com
# 22                             westdesmoinesguide.com
# 23                                     gothatoday.com
# 24                           wealthmanagementwire.com
# 25                                albusinessdaily.com
# 26                                    waukeetimes.com
# 27                             cropprotectionnews.com
# 28                                  fdahealthnews.com
# 29                                    hrdailywire.com
# 30                           americanpharmacynews.com
# 31         wvrecord.pli-records-staging.locallabs.com
# 32                                    glendalesun.com
# 33                                    cretereview.com
# 34                                   patientdaily.com
# 35                                  johnstontimes.com
# 36                                hansondirectory.com
# 37                           metrobusinessnetwork.com
# 38                               hunterscreeknews.com
# 39       pennrecord.pli-records-staging.locallabs.com
# 40                               collegeparktoday.com
# 41                              farminsurancenews.com
# 42                                surprisejournal.com
# 43                               montgomerymdnews.com
# 44                             balkanbusinesswire.com
# 45                                windermeretoday.com
# 46                                     epnewswire.com
# 47                                      clivenews.com
# 48                               homes1.statesman.com
# 49                                 cistranfinance.com
# 50                                wcminnesotanews.com
# 51                          propertyinsurancewire.com
