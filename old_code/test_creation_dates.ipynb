# %% [markdown]
# # get creation dates

# %%
from twarc import Twarc
import pandas as pd

# Set up link to Twitter
secretfile='/Users/sara/twittersecrets.txt'
with open(secretfile, 'r') as fsecret: 
  secrets = fsecret.readline()
access_token, access_token_secret, consumer_key, consumer_secret = \
    [x.strip() for x in secrets.split(',')]
twarc = Twarc(consumer_key, consumer_secret, access_token, access_token_secret)

# %%
# Read data from your CSV file - put your own details in here
# usercsv = pd.read_csv('userdeets.csv')
# usernames = usercsv['usernames'].tolist()
usernames = ['bodaceacat', 'xxevgnjb3342', 'rungrage'] #comment this out

allusers = []
for user in twarc.user_lookup(usernames, id_type='screen_name'):
    allusers += [user]
df = pd.DataFrame(allusers)
df
# Out:
#    contributors_enabled                      created_at  default_profile  \
# 0                 False  Tue May 26 21:16:16 +0000 2009            False
# 1                 False  Sun Oct 23 04:28:49 +0000 2011            False
#
#    default_profile_image                                        description  \
# 0                  False  Geek who loves hard data problems and infectin...
# 1                  False  Non serviam. Trying to glue cyber operations w...
#
#                                             entities  favourites_count  \
# 0  {'url': {'urls': [{'url': 'https://t.co/keSTIG...              1482
# 1  {'url': {'urls': [{'url': 'https://t.co/rAS0bW...              3429
#
#    follow_request_sent  followers_count  following  ...  protected  \
# 0                False             1875      False  ...      False
# 1                False             1257       True  ...      False
#
#    screen_name                                             status  \
# ...

# %%
df[['screen_name', 'created_at']].to_csv('names_with_creation_dates.csv', index=False)
df[['screen_name', 'created_at']].sort_values('created_at', ascending=False)
# Out:
#   screen_name                      created_at
# 0  bodaceacat  Tue May 26 21:16:16 +0000 2009
# 1    RungRage  Sun Oct 23 04:28:49 +0000 2011
