# %% [markdown]
# # Scrape Uni Arkansas COSMOS list

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
import re
import os

if not os.path.exists('data/scrapes'):
    os.makedirs('data/scrapes')

baseurl = 'http://cosmos.ualr.edu/misinformation'

html = requests.get(baseurl.format(0)).text
soup = bs(html, 'lxml')
rescount = int(soup.find('li', id='resultsCounterWrapper').find('span').text)
print('{} entries in database'.format(rescount))

entries = soup.find_all('li', id='misinfo')
print('{} actual entries'.format(len(entries)))

entryarr = []
for i, entry in enumerate(entries): 

    #Want to grab category, title, text, date, debunker
    titleset = entry.find('p', id='title')
    category = titleset.find('span', id='tag').text
    title = titleset.find('span', id='text').text
    description = entry.find('p', id='description').text
    if entry.find('li', id='debunkedBy') == None:
        debunkdate = ''
        debunkedby = ''
        debunkedbyurl = ''
    else:
        debunkdate = entry.find('li', id='debunkDate').find('p', id='value').text
        debunkedby = entry.find('li', id='debunkedBy').find('p', id='value').text.strip()
        debunkedbyurl = entry.find('li', id='debunkedBy').find('a').get('href')
    #published = 
    #entry.find('li', id='published') #.find('p', id='value')
    sourcecomment = entry.find(text=re.compile("Sources"))
    sources = bs(sourcecomment).find('p', id='value').text
    pubcomment = entry.find(text=re.compile("Published"))
    published = bs(pubcomment).find('p', id='value').text
    entryarr += [[i, category, title, description, debunkdate, 
                  debunkedby, debunkedbyurl, sources, published]]

df = pd.DataFrame(entryarr, columns=['index', 'category', 'title', 
                                    'description', 'debunk_date', 
                                    'debunked_by', 'debunkedby_url',
                                    'sources', 'published'])
df.to_csv('data/scrapes/CosmosC19.csv', index=False)
df
# Out:
# 382 entries in database
# 382 actual entries
#      index     category                                              title  \
# 0        0         Scam                              "Blessing Looms" scam
# 1        1  False Claim  Injecting or ingesting disinfectant may cure C...
# 2        2  False Claim  Former U.S. Rep. Trey Gowdy penned a text sugg...
# 3        3  False Claim  Joe Diffie’s death was labeled as a COVID-19 d...
# 4        4  False Claim  Kennedy Center, PBS donated to Democrats after...
# 5        5  False Claim              Nigerians are burning Chinese stores.
# 6        6  False Claim  This is COVID-19, not COVID-1, folks. You woul...
# 7        7  False Claim  "Hot mic" video from a White House coronavirus...
# 8        8  False Claim  [I]f it(COVID-19) was as infectious as they’re...
# 9        9      Mislead  Arkansas is doing very well in terms of per ca...
# 10      10  False Claim                 Children 'Do Not Die' of COVID-19.
# 11      11  False Claim  Democrats are on vacation until May 4 and “ref...
# 12      12  False Claim  My wife is suffering from coronavirus and she ...
# 13      13      Mislead  U.S. millionaires will each receive an average...
# 14      14  False Claim  Wisconsin’s in-person election has caused a “s...
# 15      15         Scam                                     CVS email scam
# 16      16  False Claim  News photo from stay-at-home protest was docto...
# 17      17  False Claim  SARS-CoV-2, the virus that led to the global c...
# 18      18  False Claim  ‘Secret Muslim’ Bill Gates Created Coronavirus...
# 19      19  False Claim  There are “360,000 (deaths) a year from swimmi...
# 20      20  False Claim  U.S. President Donald Trump tweeted in Novembe...
# 21      21         Scam  Virus Warning: This Mask can Add An Extra Laye...
# 22      22  False Claim  All Vegas hotels but Trump’s have donated food...
# 14   The false claim is: "Wisconsin’s in-person ele...  04/21/2020
# 15   A scam email is going around purporting to be ...
# 16   The false claim is: "News photo from stay-at-h...  04/19/2020
# 17   The false claim is: "SARS-CoV-2, the virus tha...  04/19/2020
# 18   The false claim is: "‘Secret Muslim’ Bill Gate...  04/17/2020
# 19   The false claim is: "There are '360,000 (death...  04/17/2020
# 20   The false claim is:"U.S. President Donald Trum...  04/17/2020
# 21   The Scam is: "Virus Warning: This Mask can Add...  04/17/2020
# 22   The false claim is: "All Vegas hotels but Trum...  04/16/2020
# 23   A San Diego physician sold an undercover FBI a...  04/16/2020
# 24   The scam is: "Someone who came in contract wit...  04/16/2020
# 25   Police are warning cell phone users of a new t...  04/16/2020
# 26   The false claim is: "Corona is so bad, this gu...  04/15/2020
# 27   The false claim is: "Hydroxychloroquine is 'a ...  04/15/2020
# 28   The scam is: "Free groceries from Walmart sent...  04/15/2020
# 29   The false claim is: "COVID-19 is caused by an ...  04/14/2020
# ..                                                 ...         ...
# 352  The false claim is: "Oregano Oil Proves Effect...  02/01/2020
# 353  The false claim is: "Coronavirus is an America...  02/01/2020
# 354  The false claim is: "Due to the situation in t...  01/31/2020
# 355  The false narrative is: "The coronavirus is an...  01/31/2020
# 356  The false narrative is: "Baba Vanga have predi...  01/30/2020
# 357  The false claim is: "Cocaine kills coronavirus...  01/30/2020
# 358  The misleading claim is: "Full-front disinfect...  01/30/2020
# 359  The false claim is: "Russian doctors have foun...  01/30/2020
# 360  The false claim is: "It is entirely possible t...  01/30/2020
# 361  The false narrative is: "Coronavirus is a West...  01/30/2020
# 362  The false narrative is: "The coronavirus is he...  01/29/2020
# 363  The false narrative is: "The coronavirus is pa...  01/29/2020
# 364  The false narrative is: "The UK and US benefit...  01/28/2020
# 365  The false claim is: "The China coronavirus is ...  01/28/2020
# 366  The false narrative is: "The apocalyptic cover...  01/28/2020
# 367  The false narrative is: "The coronavirus 2019-...  01/28/2020
# 368  The false claim is: "The coronavirus was stole...  01/28/2020
# 369  Chinese State Media and a government official ...  01/27/2020
# 370  The false narrative is: "Mutation, secret labo...  01/27/2020
# 371  The false narrative is: "The coronavirus will ...  01/27/2020
# 372  The false narrative is: "The China coronavirus...  01/27/2020
# 373  The false claim is: The coronavirus or COVID-1...  01/27/2020
# 374  The false narrative is: "There is a parallel b...  01/27/2020
# 375  The false narrative is: "For 30 years virus of...  01/26/2020
# 376  This false narrative is: "It is not a coincide...  01/25/2020
# 377  The false claim is: "The deadly new coronaviru...  01/25/2020
# 378  The false narrative is: "A deciphered predicti...  01/24/2020
# 379  The false narrative is: "China is preparing to...  01/24/2020
# 380  The false narrative is: "The appearance of cor...  01/23/2020
# 381  The false narrative is: "A new coronavirus coi...  01/22/2020
#
#               debunked_by                                     debunkedby_url  \
# 0                 content  https://content.govdelivery.com/accounts/ARAG/...
# 1                  snopes  https://www.snopes.com/fact-check/trump-disinf...
# 2                  snopes   https://www.snopes.com/fact-check/gowdy-covid19/
# 3              politifact  https://www.politifact.com/factchecks/2020/apr...
# 4              politifact  https://www.politifact.com/factchecks/2020/apr...
